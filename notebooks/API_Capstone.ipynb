# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from owid import catalog

# %% [markdown]
# ## Loads

# %%
tables = catalog.find('share_of_agriculture_in_gdp')
tables
# Out:
#                              table                      dataset     version  \
# 13426  share_of_agriculture_in_gdp  share_of_agriculture_in_gdp  2023-10-04
#
#          namespace channel  is_public       dimensions  \
# 13426  agriculture  garden       True  [country, year]
#
#                                                     path    formats
# 13426  garden/agriculture/2023-10-04/share_of_agricul...  [feather]

# %%
df = tables.iloc[0].load()
df
# Out:
#                      share_of_agriculture_in_gdp_at_current_prices__herrendorf_et_al__and_ggdc_10_data  \
# country        year
# Sweden         1800                                          40.799999
#                1801                                          38.799999
# United Kingdom 1801                                          31.600000
# Sweden         1802                                          38.599998
#                1803                                          37.599998
# ...                                                                ...
# Egypt          2013                                          14.700000
# United States  2013                                           1.300000
#                2014                                           1.200000
#                2015                                           1.000000
#                2016                                           0.900000
#
# ...

# %%
df.metadata
# Out:
# TableMeta(short_name='share_of_agriculture_in_gdp', title='Share of agriculture in GDP at current prices (Herrendorf et al. and GGDC-10 data) (split)', description='', dataset=DatasetMeta(channel='garden', namespace='agriculture', short_name='share_of_agriculture_in_gdp', title='Share of agriculture in GDP at current prices (Herrendorf et al. and GGDC-10 data) (split)', description='', sources=[Source(name='Our World In Data based on Herrendorf et al. (2014) and GGDC-10 (2015)', description='For Belgium, Spain, France, Japan, South Korea, the Netherlands, Sweden, the UK, and the USA, observations in this dataset correspond to the data published by Herrendorf, Rogerson, and Valentinyi (2014), except in some cases where we have updated observation using new releases of the same underlying data sources. The most important update corresponds to the 2015 release of the Groningen Growth and Development Centre’s (GGDC) 10-sector database. However, some other country-specific updates were al
# ...

# %%
import matplotlib.pyplot as plt

# Assuming 'table' is your Table instance and 'Year' is in the index.
# Assuming 'VariableName' is the name of the column you want to plot.

# Step 1: Select the variable
variable_series = df['value']

# Step 2: Plot the variable over time
variable_series.plot(kind='line')

plt.title('Variable over Time')
plt.xlabel('Year')
plt.ylabel('VariableName')

# Show the plot
plt.show()

# %% [markdown]
# #### Population and Demography

# %% [markdown]
# #### Life Expectancy

# %% [markdown]
# #### Economy

# %%
tables = catalog.find('penn')
tables
# Out:
#                   table           dataset     version namespace channel  \
# 12085  penn_world_table  penn_world_table  2022-11-28      ggdc  garden
#
#        is_public dimensions  \
# 12085       True         []
#
#                                                     path    formats
# 12085  garden/ggdc/2022-11-28/penn_world_table/penn_w...  [feather]

# %%
df = tables.iloc[0].load()
df
# Out:
#            country  year         rgdpe         rgdpo         pop        emp  \
# 0      Afghanistan  1970           NaN           NaN         NaN        NaN
# 1      Afghanistan  1971           NaN           NaN         NaN        NaN
# 2      Afghanistan  1972           NaN           NaN         NaN        NaN
# 3      Afghanistan  1973           NaN           NaN         NaN        NaN
# 4      Afghanistan  1974           NaN           NaN         NaN        NaN
# ...            ...   ...           ...           ...         ...        ...
# 14257     Zimbabwe  2015  4.014162e+10  3.979864e+10  13814629.0  6393751.5
# 14258     Zimbabwe  2016  4.187520e+10  4.096319e+10  14030331.0  6504373.5
# 14259     Zimbabwe  2017  4.467218e+10  4.431674e+10  14236595.0  6611773.0
# 14260     Zimbabwe  2018  4.432511e+10  4.342090e+10  14438802.0  6714952.0
# 14261     Zimbabwe  2019  4.229606e+10  4.082657e+10  14645468.0  6831016.5
#
# ...

# %% [markdown]
# #### Energy

# %% [markdown]
# #### Urbanization and Pop Density

# %% [markdown]
# ## Processing

# %% [markdown]
# #### Standardize formats

# %% [markdown]
# #### Merging data

# %% [markdown]
# ## Analysis

# %%
tables = catalog.find('urbanization')
tables
# Out:
#                           table                   dataset     version  \
# 14604  urbanization_urban_rural  urbanization_urban_rural  2024-01-17
#
#       namespace channel  is_public       dimensions  \
# 14604        un  garden       True  [country, year]
#
#                                                     path    formats
# 14604  garden/un/2024-01-17/urbanization_urban_rural/...  [feather]

# %%
df = tables.iloc[0].load()
type(df)
# Out:
# owid.catalog.tables.Table

# %%
df.metadata
# Out:
# TableMeta(short_name='urbanization_urban_rural', title='World Urbanization Prospects Dataset', description='This dataset is derived from the World Urbanization Prospects, providing comprehensive data on global urbanization trends, including population figures, urban and rural population distributions, and projections for future urban growth.', dataset=DatasetMeta(channel='garden', namespace='un', short_name='urbanization_urban_rural', title='World Urbanization Prospects Dataset - Urban and Rural Population', description='This dataset is derived from the World Urbanization Prospects, providing comprehensive data on global urbanization trends, including population figures, urban and rural population distributions, and projections for future urban growth.', sources=[], licenses=[], is_public=True, additional_info=None, version='2024-01-17', source_checksum='e862f6741d55a1859a6ee02cd6d99031'), primary_key=['country', 'year'])

# %%
catalog.find('penn')
# Out:
#                   table           dataset     version namespace channel  \
# 12070  penn_world_table  penn_world_table  2022-11-28      ggdc  garden
#
#        is_public dimensions  \
# 12070       True         []
#
#                                                     path    formats
# 12070  garden/ggdc/2022-11-28/penn_world_table/penn_w...  [feather]
